# %% [markdown]
# # How many infants are anaemic in india
#
# **Dataset:** RBI Handbook of Statistics on Indian States

# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd

# %%
df = pd.read_excel('Rbi_Data_ANAEMIA.xlsx')

# %%
df.head(9)
# Out:
#        State/Union Territory NFHS 3 (2005-06) NFHS 4 (2015-16)  \
# 0  Andaman & Nicobar Islands                -               49
# 1             Andhra Pradesh             70.8             58.6
# 2          Arunachal Pradesh             56.9             50.7
# 3                      Assam             69.6             35.7
# 4                      Bihar               78             63.5
# 5                 Chandigarh                -             73.1
# 6               Chhattisgarh             71.2             41.6
# 7       Dadra & Nagar Haveli                -             84.6
# 8                Daman & Diu                -             73.8
#
#   NFHS 5 (2019-21)
# 0               40
# 1             63.2
# 2             56.6
# 3             68.4
# 4             69.4
# 5             54.6
# 6             67.2
# 7            75.8#
# 8                -

# %%
df.tail(5)
# Out:
#    State/Union Territory NFHS 3 (2005-06) NFHS 4 (2015-16) NFHS 5 (2019-21)
# 33               Tripura             62.9             48.3             64.2
# 34         Uttar Pradesh             73.9             63.2             66.4
# 35           Uttarakhand             61.4             59.8             58.8
# 36           West Bengal               61             54.2               69
# 37             ALL INDIA             69.5             58.4             67.1

# %%
df.shape
# Out:
# (38, 4)

# %%
df.columns
# Out:
# Index(['State/Union Territory', 'NFHS 3 (2005-06)', 'NFHS 4 (2015-16)',
#        'NFHS 5 (2019-21)'],
#       dtype='str')

# %%
df.info()
# Out:
# <class 'pandas.DataFrame'>
# RangeIndex: 38 entries, 0 to 37
# Data columns (total 4 columns):
#  #   Column                 Non-Null Count  Dtype
# ---  ------                 --------------  -----
#  0   State/Union Territory  38 non-null     str
#  1   NFHS 3 (2005-06)       38 non-null     object
#  2   NFHS 4 (2015-16)       38 non-null     object
#  3   NFHS 5 (2019-21)       38 non-null     object
# dtypes: object(3), str(1)
# memory usage: 1.3+ KB

# %%
df.sort_values(by=['NFHS 4 (2015-16)', 'NFHS 5 (2019-21)'], ascending=True).head(5)
# Out:
#    State/Union Territory NFHS 3 (2005-06) NFHS 4 (2015-16) NFHS 5 (2019-21)
# 24               Mizoram             44.2             17.7             46.4
# 25              Nagaland                -             21.6             42.7
# 22               Manipur             41.1             23.9             42.8
# 17                Kerala             44.5             35.6             39.4
# 3                  Assam             69.6             35.7             68.4

# %% [markdown]
# ### I tried to find out top 5 states/union territories that were high on the index in the past two surveys by NFHS

# %%
df.describe()
# Out:
#             State/Union Territory NFHS 3 (2005-06)  NFHS 4 (2015-16)  \
# count                          38               38              38.0
# unique                         38               29              35.0
# top     Andaman & Nicobar Islands                -              50.7
# freq                            1                9               2.0
#
#         NFHS 5 (2019-21)
# count               38.0
# unique              37.0
# top                 64.2
# freq                 2.0

# %%
df["State/Union Territory"]
# Out:
# 0     Andaman & Nicobar Islands
# 1                Andhra Pradesh
# 2             Arunachal Pradesh
# 3                         Assam
# 4                         Bihar
# 5                    Chandigarh
# 6                  Chhattisgarh
# 7          Dadra & Nagar Haveli
# 8                   Daman & Diu
# 9                         Delhi
# 10                          Goa
# 11                      Gujarat
# 12                      Haryana
# 13             Himachal Pradesh
# 14              Jammu & Kashmir
# 15                    Jharkhand
# 16                    Karnataka
# 17                       Kerala
# 18                       Ladakh
# 19                  Lakshadweep
# 20               Madhya Pradesh
# 21                  Maharashtra
# 22                      Manipur
# 23                    Meghalaya
# 24                      Mizoram
# 25                     Nagaland
# 26                       Odisha
# 27                   Puducherry
# 28                       Punjab
# ...

# %%
df[[
    "State/Union Territory",
    "NFHS 4 (2015-16)",
    "NFHS 5 (2019-21)"
]]
# Out:
#         State/Union Territory NFHS 4 (2015-16) NFHS 5 (2019-21)
# 0   Andaman & Nicobar Islands               49               40
# 1              Andhra Pradesh             58.6             63.2
# 2           Arunachal Pradesh             50.7             56.6
# 3                       Assam             35.7             68.4
# 4                       Bihar             63.5             69.4
# 5                  Chandigarh             73.1             54.6
# 6                Chhattisgarh             41.6             67.2
# 7        Dadra & Nagar Haveli             84.6            75.8#
# 8                 Daman & Diu             73.8                -
# 9                       Delhi             62.6             69.2
# 10                        Goa             48.3             53.2
# 11                    Gujarat             62.6             79.7
# 12                    Haryana             71.7             70.4
# 13           Himachal Pradesh             53.7             55.4
# ...

# %%
df[df["State/Union Territory"] == "Goa"]
# Out:
#    State/Union Territory NFHS 3 (2005-06) NFHS 4 (2015-16) NFHS 5 (2019-21)
# 10                   Goa             38.2             48.3             53.2

# %% [markdown]
# # Tried finding out for a particular state.
